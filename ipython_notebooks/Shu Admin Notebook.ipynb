# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd
import pprint

# %%
client = dataiku.api_client()
project = client.list_projects()
project = client.get_default_project()

print("My project is %s" % project.project_key)
# Out:
# My project is ADMIN_PROJECT

# %%
#API reference for autodetect_settings: 
#https://doc.dataiku.com/dss/latest/python-api/datasets-reference.html
#Detects appropriate settings for this dataset using Dataiku detection engine
datasets = project.list_datasets()
index = 1
for dataset in datasets:
#    if (dataset.type == 'PostgreSQL'):
    if (dataset.type != 'Snowflakeeeee'):
        print("Dataset %d" %index)
        print("Name: %s" % dataset.name)
        print("Type: %s" % dataset.type)
#       print("Connection: %s" % dataset.connection)
#       dataset1 = project.get_dataset(dataset.name), we can use to_dataset() to conver it too
        dataset1 = dataset.to_dataset()
#        print("Obj type of dataset is: %s" % type(dataset))
#        print("Attributes of dataset is: %s" %dir(dataset))
#        print("Obj type of dataset1 is: %s" % type(dataset1))
#        print("Attributes of dataset1 is: %s" %dir(dataset1))


        settings = dataset1.get_settings()
        print("Attributes of settings is: \n%s" %dir(settings))
        settings_raw = settings.get_raw()
        params = settings.get_raw_params()
        print("\n\nParams is:\n")
        pprint.pprint(params)
        print("\n\nSettings raw is:\n")
        pprint.pprint(settings_raw)
        index += 1
        
        #modify schma of dataset
        #https://doc.dataiku.com/dss/latest/python-api/datasets-other.html#basic-operations
#        for column in settings_raw['schema']['columns']:
        # Now, let's add a new column in the schema
        #settings.add_raw_schema_column({"name" : "shelley_test", "type": "string"})     
        # If we changed the settings, we must save
        #settings.save()
        
        for column in settings.schema_columns :
            if column["name"] == 'shelley_test':
                print("Have column name=%s type=%s" % (column["name"], column["type"]))        
#        break
# Out:
# Dataset 1
# Name: BASKETBALLv2_BASKETBALL_EXPERIENCE_SF
# Type: Snowflake
# Attributes of settings is:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_tod', 'add_discrete_partitioning_dimension', 'add_raw_schema_column', 'add_time_partitioning_dimension', 'custom_fields', 'dataset', 'description', 'get_raw', 'get_raw_params', 'remove_partitioning', 'save', 'schema_columns', 'set_table', 'settings', 'short_description', 'tags', 'type']
#
#
# Params is:
#
# {'catalog': 'INTEGRATION_TESTS',
#  'connection': 'test_snowflake',
#  'mode': 'table',
#  'normalizeDoubles': True,
#  'notReadyIfEmpty': False,
#  'partitioningType': 'custom',
#  'readColsWithUnknownTzAsDates': False,
#  'readSQLDateColsAsDSSDates': True,
#  'schema': '',
#  'table': 'BASKETBALLv2_BASKETBALL_EXPERIENCE_SF',
#  'tableCreationMode': 'auto',
#  'writeInsertBatchSize': 10000,
#  'writeJDBCBadDataBehavior': 'DISCARD_ROW'}
#
#
# Settings raw is:
#
# {'checklists': {'checklists': []},
#  'creationTag': {'lastModifiedBy': {'login': 'admin'},
#                  'lastModifiedOn': 1649353647352,
#                  'versionNumber': 0},
#  'customFields': {},
#  'customMeta': {'kv': {}},
#  'dkuProperties': [],
#  'flowOptions': {'crossProjectBuildBehavior': 'DEFAULT',
#                  'rebuildBehavior': 'NORMAL',
#                  'virtualizable': False},
#  'managed': False,
#  'metrics': {'displayedState': {'columns': [],
#                                 'metrics': ['basic:COUNT_COLUMNS',
#                                             'records:COUNT_RECORDS']},
#              'engineConfig': {'basic': {},
#                               'dss': {'active': True,
#                                       'selection': {'filter': {'distinct': False,
#                                                                'enabled': False},
#                                                     'latestPartitionsN': 1,
#                                                     'maxReadUncompressedBytes': -1,
#                                                     'maxRecords': -1,
#                                                     'ordering': {'enabled': False,
#                                                                  'rules': []},
#                                                     'partitionSelectionMethod': 'ALL',
#                                                     'samplingMethod': 'FULL',
#                                                     'targetRatio': 0.02,
#                                                     'useMemTable': False,
#                                                     'withinFirstN': -1}},
#                               'hive': {'active': True, 'extraConf': []},
#                               'impala': {'active': True},
#                               'padRunsWithMetrics': False,
#                               'python': {},
#                               'spark': {'active': True, 'extraConf': []},
#                               'sql': {'active': True}},
#              'probes': [{'computeOnBuildMode': 'PARTITION',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Basic data'},
#                          'type': 'basic'},
#                         {'computeOnBuildMode': 'NO',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Record count'},
#                          'type': 'records'}]},
#  'metricsChecks': {'checks': [],
#                    'displayedState': {'checks': []},
#                    'runOnBuild': False},
#  'name': 'BASKETBALLv2_BASKETBALL_EXPERIENCE_SF',
#  'params': {'catalog': 'INTEGRATION_TESTS',
#             'connection': 'test_snowflake',
#             'mode': 'table',
#             'normalizeDoubles': True,
#             'notReadyIfEmpty': False,
#             'partitioningType': 'custom',
#             'readColsWithUnknownTzAsDates': False,
#             'readSQLDateColsAsDSSDates': True,
#             'schema': '',
#             'table': 'BASKETBALLv2_BASKETBALL_EXPERIENCE_SF',
#             'tableCreationMode': 'auto',
#             'writeInsertBatchSize': 10000,
#             'writeJDBCBadDataBehavior': 'DISCARD_ROW'},
#  'partitioning': {'considerMissingRequestedPartitionsAsEmpty': False,
#                   'dimensions': [],
#                   'ignoreNonMatchingFile': False},
#  'projectKey': 'ADMIN_PROJECT',
#  'readWriteOptions': {'defaultReadOrdering': {'enabled': False, 'rules': []},
#                       'forceSingleOutputFile': False,
#                       'preserveOrder': False,
#                       'writeBuckets': 1},
#  'schema': {'columns': [{'maxLength': 4194304,
#                          'name': 'Player',
#                          'originalType': 'VARCHAR',
#                          'type': 'string'},
#                         {'name': '1980_sum',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'name': 'Age_min',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'name': 'Year',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'maxLength': 4194304,
#                          'name': 'Pos',
#                          'originalType': 'VARCHAR',
#                          'type': 'string'},
#                         {'name': 'Age',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'maxLength': 4194304,
#                          'name': 'Tm',
#                          'originalType': 'VARCHAR',
#                          'type': 'string'},
#                         {'name': 'has_TOT',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'name': 'G',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'maxLength': 4194304,
#                          'name': 'Injury',
#                          'originalType': 'VARCHAR',
#                          'type': 'string'},
#                         {'name': 'GS',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'},
#                         {'name': 'MP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FG',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FGA',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FGP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '3P',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '3PA',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '3PP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '2P',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '2PA',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': '2PP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'EFGP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FT',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FTA',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'FTP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'ORB',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'DRB',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'TRB',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'AST',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'STL',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'BLK',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'TO',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'PF',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'PTS',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'Exp',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'}],
#             'userModified': True},
#  'smartName': 'BASKETBALLv2_BASKETBALL_EXPERIENCE_SF',
#  'tags': [],
#  'type': 'Snowflake',
#  'versionTag': {'lastModifiedBy': {'login': 'admin'},
#                 'lastModifiedOn': 1649353647352,
#                 'versionNumber': 0}}
# Dataset 2
# Name: Basketball_Experience_SQL_result
# Type: PostgreSQL
# Attributes of settings is:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_tod', 'add_discrete_partitioning_dimension', 'add_raw_schema_column', 'add_time_partitioning_dimension', 'custom_fields', 'dataset', 'description', 'get_raw', 'get_raw_params', 'remove_partitioning', 'save', 'schema_columns', 'set_table', 'settings', 'short_description', 'tags', 'type']
#
#
# Params is:
#
# {'connection': 'postgres_conn',
#  'mode': 'table',
#  'normalizeDoubles': True,
#  'notReadyIfEmpty': False,
#  'partitioningType': 'custom',
#  'readColsWithUnknownTzAsDates': False,
#  'readSQLDateColsAsDSSDates': True,
#  'table': '${projectKey}_basketball_experience_sql_result',
#  'tableCreationMode': 'auto',
#  'writeInsertBatchSize': 10000,
#  'writeJDBCBadDataBehavior': 'DISCARD_ROW',
#  'writeWithCopyBadDataBehavior': 'NOVERIFY_ERROR'}
#
#
# Settings raw is:
#
# {'checklists': {'checklists': []},
#  'checks': [],
#  'creationTag': {'lastModifiedBy': {'login': 'admin'},
#                  'lastModifiedOn': 1649352157692,
#                  'versionNumber': 0},
#  'customFields': {},
#  'customMeta': {'kv': {}},
#  'dkuProperties': [],
#  'flowOptions': {'crossProjectBuildBehavior': 'DEFAULT',
#                  'rebuildBehavior': 'NORMAL',
#                  'virtualizable': False},
#  'managed': True,
#  'metrics': {'displayedState': {'columns': [],
#                                 'metrics': ['basic:COUNT_COLUMNS',
#                                             'records:COUNT_RECORDS']},
#              'engineConfig': {'basic': {},
#                               'dss': {'active': True,
#                                       'selection': {'filter': {'distinct': False,
#                                                                'enabled': False},
#                                                     'latestPartitionsN': 1,
#                                                     'maxReadUncompressedBytes': -1,
#                                                     'maxRecords': -1,
#                                                     'ordering': {'enabled': False,
#                                                                  'rules': []},
#                                                     'partitionSelectionMethod': 'ALL',
#                                                     'samplingMethod': 'FULL',
#                                                     'targetRatio': 0.02,
#                                                     'useMemTable': False,
#                                                     'withinFirstN': -1}},
#                               'hive': {'active': True, 'extraConf': []},
#                               'impala': {'active': True},
#                               'padRunsWithMetrics': False,
#                               'python': {},
#                               'spark': {'active': True, 'extraConf': []},
#                               'sql': {'active': True}},
#              'probes': [{'computeOnBuildMode': 'PARTITION',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Basic data'},
#                          'type': 'basic'},
#                         {'computeOnBuildMode': 'NO',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Record count'},
#                          'type': 'records'}]},
#  'metricsChecks': {'checks': [],
#                    'displayedState': {'checks': []},
#                    'runOnBuild': False},
#  'name': 'Basketball_Experience_SQL_result',
#  'params': {'connection': 'postgres_conn',
#             'mode': 'table',
#             'normalizeDoubles': True,
#             'notReadyIfEmpty': False,
#             'partitioningType': 'custom',
#             'readColsWithUnknownTzAsDates': False,
#             'readSQLDateColsAsDSSDates': True,
#             'table': '${projectKey}_basketball_experience_sql_result',
#             'tableCreationMode': 'auto',
#             'writeInsertBatchSize': 10000,
#             'writeJDBCBadDataBehavior': 'DISCARD_ROW',
#             'writeWithCopyBadDataBehavior': 'NOVERIFY_ERROR'},
#  'partitioning': {'considerMissingRequestedPartitionsAsEmpty': False,
#                   'dimensions': [],
#                   'ignoreNonMatchingFile': False},
#  'projectKey': 'ADMIN_PROJECT',
#  'readWriteOptions': {'defaultReadOrdering': {'enabled': False, 'rules': []},
#                       'forceSingleOutputFile': False,
#                       'preserveOrder': False,
#                       'writeBuckets': 1},
#  'schema': {'columns': [{'name': 'GS',
#                          'originalType': 'int8',
#                          'type': 'bigint'},
#                         {'name': 'Age',
#                          'originalType': 'int8',
#                          'type': 'bigint'}],
#             'userModified': True},
#  'smartName': 'Basketball_Experience_SQL_result',
#  'tags': [],
#  'type': 'PostgreSQL',
#  'versionTag': {'lastModifiedBy': {'login': 'admin'},
#                 'lastModifiedOn': 1649354472003,
#                 'versionNumber': 2}}
# Dataset 3
# Name: Basketball_experience_sql2
# Type: PostgreSQL
# Attributes of settings is:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_tod', 'add_discrete_partitioning_dimension', 'add_raw_schema_column', 'add_time_partitioning_dimension', 'custom_fields', 'dataset', 'description', 'get_raw', 'get_raw_params', 'remove_partitioning', 'save', 'schema_columns', 'set_table', 'settings', 'short_description', 'tags', 'type']
#
#
# Params is:
#
# {'connection': 'postgres_conn',
#  'mode': 'table',
#  'normalizeDoubles': True,
#  'notReadyIfEmpty': False,
#  'partitioningType': 'custom',
#  'readColsWithUnknownTzAsDates': False,
#  'readSQLDateColsAsDSSDates': True,
#  'table': '${projectKey}_basketball_experience_sql2',
#  'tableCreationMode': 'auto',
#  'writeInsertBatchSize': 10000,
#  'writeJDBCBadDataBehavior': 'DISCARD_ROW',
#  'writeWithCopyBadDataBehavior': 'NOVERIFY_ERROR'}
#
#
# Settings raw is:
#
# {'checklists': {'checklists': []},
#  'checks': [],
#  'creationTag': {'lastModifiedBy': {'login': 'admin'},
#                  'lastModifiedOn': 1649353771724,
#                  'versionNumber': 0},
#  'customFields': {},
#  'customMeta': {'kv': {}},
#  'dkuProperties': [],
#  'flowOptions': {'crossProjectBuildBehavior': 'DEFAULT',
#                  'rebuildBehavior': 'NORMAL',
#                  'virtualizable': False},
#  'managed': True,
#  'metrics': {'displayedState': {'columns': [],
#                                 'metrics': ['basic:COUNT_COLUMNS',
#                                             'records:COUNT_RECORDS']},
#              'engineConfig': {'basic': {},
#                               'dss': {'active': True,
#                                       'selection': {'filter': {'distinct': False,
#                                                                'enabled': False},
#                                                     'latestPartitionsN': 1,
#                                                     'maxReadUncompressedBytes': -1,
#                                                     'maxRecords': -1,
#                                                     'ordering': {'enabled': False,
#                                                                  'rules': []},
#                                                     'partitionSelectionMethod': 'ALL',
#                                                     'samplingMethod': 'FULL',
#                                                     'targetRatio': 0.02,
#                                                     'useMemTable': False,
#                                                     'withinFirstN': -1}},
#                               'hive': {'active': True, 'extraConf': []},
#                               'impala': {'active': True},
#                               'padRunsWithMetrics': False,
#                               'python': {},
#                               'spark': {'active': True, 'extraConf': []},
#                               'sql': {'active': True}},
#              'probes': [{'computeOnBuildMode': 'PARTITION',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Basic data'},
#                          'type': 'basic'},
#                         {'computeOnBuildMode': 'NO',
#                          'configuration': {},
#                          'enabled': True,
#                          'meta': {'level': 0, 'name': 'Record count'},
#                          'type': 'records'}]},
#  'metricsChecks': {'checks': [],
#                    'displayedState': {'checks': []},
#                    'runOnBuild': False},
#  'name': 'Basketball_experience_sql2',
#  'params': {'connection': 'postgres_conn',
#             'mode': 'table',
#             'normalizeDoubles': True,
#             'notReadyIfEmpty': False,
#             'partitioningType': 'custom',
#             'readColsWithUnknownTzAsDates': False,
#             'readSQLDateColsAsDSSDates': True,
#             'table': '${projectKey}_basketball_experience_sql2',
#             'tableCreationMode': 'auto',
#             'writeInsertBatchSize': 10000,
#             'writeJDBCBadDataBehavior': 'DISCARD_ROW',
#             'writeWithCopyBadDataBehavior': 'NOVERIFY_ERROR'},
#  'partitioning': {'considerMissingRequestedPartitionsAsEmpty': False,
#                   'dimensions': [],
#                   'ignoreNonMatchingFile': False},
#  'projectKey': 'ADMIN_PROJECT',
#  'readWriteOptions': {'defaultReadOrdering': {'enabled': False, 'rules': []},
#                       'forceSingleOutputFile': False,
#                       'preserveOrder': False,
#                       'writeBuckets': 1},
#  'schema': {'columns': [{'maxLength': 4194304,
#                          'name': 'Player',
#                          'originalType': 'VARCHAR',
#                          'type': 'string'},
#                         {'name': 'MP',
#                          'originalType': 'DOUBLE',
#                          'type': 'double'},
#                         {'name': 'Age',
#                          'originalType': 'NUMBER',
#                          'type': 'bigint'}],
#             'userModified': True},
#  'smartName': 'Basketball_experience_sql2',
#  'tags': [],
#  'type': 'PostgreSQL',
#  'versionTag': {'lastModifiedBy': {'login': 'admin'},
#                 'lastModifiedOn': 1649354529616,
#                 'versionNumber': 3}}
