# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
#This is a notebook for envs
import os
 
for k, v in os.environ.items():
    print(f'{k}={v}')
# Out:
# DKU_EVENTSERVER_JAVA_OPTS=-Xmx2g -XX:+UseG1GC -Xloggc:/dev/stderr -XX:+PrintGCTimeStamps
# LC_ALL=en_US.UTF-8
# DKUCAKBIN=/data/dataiku/data_dir/bin/cak
# DKU_BACKEND_JAVA_OPTS=-Xmx4g -XX:+UseG1GC -Xloggc:/dev/stderr -XX:+PrintGCTimeStamps
# DKU_IPYTHON_PORT=11002
# DKU_EVENTSERVER_JAVA_LIBRARY_PATH=
# LANG=en_US.UTF-8
# HISTCONTROL=ignoredups
# DKUHPROXYBIN=/data/dataiku/data_dir/bin/hproxy
# HOSTNAME=shelley-dss-design
# SPARKR_DRIVER_R=/usr/bin/R
# OLDPWD=/home/dataiku
# DKUDISTRIB=centos 8
# DKURUNDIR=/data/dataiku/data_dir/run
# DKU_EVENTSERVER_PORT=11004
# DKU_HADOOP_VERSION_STRING=dss-standalone-libs-generic-hadoop3
# DKUINSTALLDIR=/data/dataiku/dataiku-dss-10.0.3
# DKU_JEK_JAVA_OPTS=-Xmx2g -XX:+UseParallelGC -Xloggc:/dev/stderr -XX:+PrintGCDetails -XX:+PrintGCTimeStamps
# DKU_HPROXY_JAVA_OPTS=-Xmx2g -XX:+UseParallelGC -Xloggc:/dev/stderr -XX:+PrintGCDetails -XX:+PrintGCTimeStamps
# DKU_RLIBS_SET=1
# JUPYTER_DATA_DIR=/data/dataiku/data_dir/jupyter-run/jupyter
# ...

# %%
#set th google service account credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/home/dataiku/shelley-adm-training-6e30939426c4.json"
print("\n\nSHUDEBUG: find out if GKEY is set of not")
GKEY = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
print(GKEY)
# Out:
# SHUDEBUG: find out if GKEY is set of not
# /home/dataiku/shelley-adm-training-6e30939426c4.json
